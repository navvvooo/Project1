# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\User\Downloads\DDW-0000C-24.csv')
df.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'C-24 DISABLED NON-WORKERS BY TYPE OF DISABILITY AND SEX', 'Unnamed: 6',
#        'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11',
#        'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15',
#        'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19',
#        'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23',
#        'Unnamed: 24', 'Unnamed: 25', 'Unnamed: 26', 'Unnamed: 27',
#        'Unnamed: 28', 'Unnamed: 29', 'Unnamed: 30', 'Unnamed: 31',
#        'Unnamed: 32', 'Unnamed: 33'],
#       dtype='object')

# %%
df.head(10)
# Out:
#   Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0      Table      State     Distt.  Area Name     Total/
# 1       Name       Code       Code        NaN     Rural/
# 2        NaN        NaN        NaN        NaN     Urban/
# 3        NaN        NaN        NaN        NaN        NaN
# 4        NaN        NaN        NaN        NaN        NaN
# 5        NaN        NaN        NaN        NaN        NaN
# 6      C2324         00        000      INDIA      Total
# 7      C2324         00        000      INDIA      Total
# 8      C2324         00        000      INDIA      Total
# 9      C2324         00        000      INDIA      Total
#
#   C-24 DISABLED NON-WORKERS BY TYPE OF DISABILITY AND SEX  \
# 0                             Activity of Non-worker
# 1                                                NaN
# 2                                                NaN
# 3                                                  1
# 4                                                NaN
# ...

# %%
df1=df[[ 'Unnamed: 3',
                       'Unnamed: 4','C-24 DISABLED NON-WORKERS BY TYPE OF DISABILITY AND SEX', 'Unnamed: 6']]
data =df1.copy()
data.head(20)
# Out:
#    Unnamed: 3 Unnamed: 4  \
# 0   Area Name     Total/
# 1         NaN     Rural/
# 2         NaN     Urban/
# 3         NaN        NaN
# 4         NaN        NaN
# 5         NaN        NaN
# 6       INDIA      Total
# 7       INDIA      Total
# 8       INDIA      Total
# 9       INDIA      Total
# 10      INDIA      Total
# 11      INDIA      Total
# 12      INDIA      Total
# 13      INDIA      Total
# 14      INDIA      Rural
# 15      INDIA      Rural
# 16      INDIA      Rural
# 17      INDIA      Rural
# 18      INDIA      Rural
# 19      INDIA      Rural
#
#    C-24 DISABLED NON-WORKERS BY TYPE OF DISABILITY AND SEX  \
# 0                              Activity of Non-worker
# 1                                                 NaN
# 2                                                 NaN
# 3                                                   1
# 4                                                 NaN
# 5                                                 NaN
# ...

# %%
data.loc[data['Unnamed: 4']=='Total']
# Out:
#                                  Unnamed: 3 Unnamed: 4  \
# 6                                     INDIA      Total
# 7                                     INDIA      Total
# 8                                     INDIA      Total
# 9                                     INDIA      Total
# 10                                    INDIA      Total
# ..                                      ...        ...
# 849  State - ANDAMAN & NICOBAR ISLANDS (35)      Total
# 850  State - ANDAMAN & NICOBAR ISLANDS (35)      Total
# 851  State - ANDAMAN & NICOBAR ISLANDS (35)      Total
# 852  State - ANDAMAN & NICOBAR ISLANDS (35)      Total
# 853  State - ANDAMAN & NICOBAR ISLANDS (35)      Total
#
#     C-24 DISABLED NON-WORKERS BY TYPE OF DISABILITY AND SEX Unnamed: 6
# 6                                                Total        17070608
# 7                                              Student         4638653
# 8                                     Household duties         2618327
# ...

# %%
f =data.iloc[30:, :]
f.head(20)
# Out:
#                       Unnamed: 3 Unnamed: 4  \
# 30  State - JAMMU & KASHMIR (01)      Total
# 31  State - JAMMU & KASHMIR (01)      Total
# 32  State - JAMMU & KASHMIR (01)      Total
# 33  State - JAMMU & KASHMIR (01)      Total
# 34  State - JAMMU & KASHMIR (01)      Total
# 35  State - JAMMU & KASHMIR (01)      Total
# 36  State - JAMMU & KASHMIR (01)      Total
# 37  State - JAMMU & KASHMIR (01)      Total
# 38  State - JAMMU & KASHMIR (01)      Rural
# 39  State - JAMMU & KASHMIR (01)      Rural
# 40  State - JAMMU & KASHMIR (01)      Rural
# 41  State - JAMMU & KASHMIR (01)      Rural
# 42  State - JAMMU & KASHMIR (01)      Rural
# 43  State - JAMMU & KASHMIR (01)      Rural
# 44  State - JAMMU & KASHMIR (01)      Rural
# 45  State - JAMMU & KASHMIR (01)      Rural
# 46  State - JAMMU & KASHMIR (01)      Urban
# 47  State - JAMMU & KASHMIR (01)      Urban
# 48  State - JAMMU & KASHMIR (01)      Urban
# 49  State - JAMMU & KASHMIR (01)      Urban
#
# ...

# %%
data2 = f.loc[f['C-24 DISABLED NON-WORKERS BY TYPE OF DISABILITY AND SEX'] =='Total']
data2
# Out:
#                                  Unnamed: 3 Unnamed: 4  \
# 30             State - JAMMU & KASHMIR (01)      Total
# 38             State - JAMMU & KASHMIR (01)      Rural
# 46             State - JAMMU & KASHMIR (01)      Urban
# 54            State - HIMACHAL PRADESH (02)      Total
# 62            State - HIMACHAL PRADESH (02)      Rural
# ..                                      ...        ...
# 830                 State - PUDUCHERRY (34)      Rural
# 838                 State - PUDUCHERRY (34)      Urban
# 846  State - ANDAMAN & NICOBAR ISLANDS (35)      Total
# 854  State - ANDAMAN & NICOBAR ISLANDS (35)      Rural
# 862  State - ANDAMAN & NICOBAR ISLANDS (35)      Urban
#
#     C-24 DISABLED NON-WORKERS BY TYPE OF DISABILITY AND SEX Unnamed: 6
# 30                                               Total          239621
# 38                                               Total          182583
# 46                                               Total           57038
# ...

# %%
g= data2.sort_values(by=['Unnamed: 4','Unnamed: 3'])
g
# Out:
#                                  Unnamed: 3 Unnamed: 4  \
# 854  State - ANDAMAN & NICOBAR ISLANDS (35)      Rural
# 686             State - ANDHRA PRADESH (28)      Rural
# 302          State - ARUNACHAL PRADESH (12)      Rural
# 446                      State - ASSAM (18)      Rural
# 254                      State - BIHAR (10)      Rural
# ..                                      ...        ...
# 814                 State - TAMIL NADU (33)      Urban
# 406                    State - TRIPURA (16)      Urban
# 238              State - UTTAR PRADESH (09)      Urban
# 142                State - UTTARAKHAND (05)      Urban
# 478                State - WEST BENGAL (19)      Urban
#
#     C-24 DISABLED NON-WORKERS BY TYPE OF DISABILITY AND SEX Unnamed: 6
# 854                                              Total            3369
# 686                                              Total          904121
# 302                                              Total           12049
# ...
